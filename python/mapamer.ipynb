# %%
import folium
import pandas as pd

# Define a function to categorize states based on political affiliation
def categorize_political_affiliation(state):
    democratic_states = ["California", "New York", "Massachusetts", "Washington", "Oregon", "Minnesota", "Hawaii"]
    republican_states = ["Texas", "Florida", "Georgia", "Ohio", "North Carolina", "Idaho", "Wyoming", "Utah", "Alaska", "Oklahoma", "Kansas", "Nebraska", "South Dakota", "North Dakota", "Alabama", "Mississippi", "South Carolina"]
    
    if state in democratic_states:
        return "Democratic"
    elif state in republican_states:
        return "Republican"
    else:
        return "Unknown"

# Create a DataFrame with state names
us_states_df = pd.DataFrame({"State": ["California", "Texas", "Florida", "New York", "Washington", "Oregon", "Arizona", "Colorado", "Illinois", "Michigan", "Ohio"]})

# Categorize states based on political affiliation
us_states_df["political_affiliation"] = us_states_df["State"].apply(categorize_political_affiliation)

# Create a folium map
us_map = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add state boundaries to the map
for index, row in us_states_df.iterrows():
    state = row["State"]
    political_affiliation = row["political_affiliation"]
    
    # Define color based on political affiliation
    if political_affiliation == "Democratic":
        color = "blue"
    elif political_affiliation == "Republican":
        color = "red"
    else:
        color = "gray"
    
    # Add state boundaries to the map
    folium.Marker(location=[0, 0], tooltip=state, icon=folium.Icon(color=color)).add_to(us_map)

# Display the map
us_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
import pandas as pd
import matplotlib.pyplot as plt

# Define functions to categorize states based on different criteria
def categorize_political_affiliation(state):
    democratic_states = ["California", "New York", "Massachusetts", "Washington", "Oregon", "Minnesota", "Hawaii"]
    republican_states = ["Texas", "Florida", "Georgia", "Ohio", "North Carolina", "Idaho", "Wyoming", "Utah", "Alaska", "Oklahoma", "Kansas", "Nebraska", "South Dakota", "North Dakota", "Alabama", "Mississippi", "South Carolina"]
    
    if state in democratic_states:
        return "Democratic"
    elif state in republican_states:
        return "Republican"
    else:
        return "Unknown"

def categorize_death_penalty(state):
    death_penalty_states = ["Texas", "Florida", "Georgia", "Ohio", "Oklahoma", "Montana", "Idaho","Nevada", "Utah", "Wyoming", "South Dakota", "Nebraska", "Kansas", "Arkansas", "Louisiana", "Mississippi","Alabama", "South Carolina", "North Carolina", "Kentucky", "Indiana"]
    
    if state in death_penalty_states:
        return "Active"
    else:
        return "Inactive"

def categorize_geopolitical_region(state):
    northeast_states = ["Connecticut", "Maine", "Massachusetts", "New Hampshire", "Rhode Island", "Vermont", "New York", "New Jersey", "Pennsylvania"]
    midwest_states = ["Illinois", "Indiana", "Michigan", "Ohio", "Wisconsin", "Iowa", "Kansas", "Minnesota", "Missouri", "Nebraska", "North Dakota", "South Dakota"]
    south_states = ["Delaware", "Florida", "Georgia", "Maryland", "North Carolina", "South Carolina", "Virginia", "West Virginia", "Alabama", "Kentucky", "Mississippi", "Tennessee", "Arkansas", "Louisiana", "Oklahoma", "Texas"]
    west_states = ["Arizona", "Colorado", "Idaho", "Montana", "Nevada", "New Mexico", "Utah", "Wyoming", "Alaska", "California", "Hawaii", "Oregon", "Washington"]
    
    if state in northeast_states:
        return "Northeast"
    elif state in midwest_states:
        return "Midwest"
    elif state in south_states:
        return "South"
    elif state in west_states:
        return "West"
    else:
        return "Unknown"

# Load state names
us_states_df = pd.DataFrame({"State": ["California", "Texas", "Florida", "New York", "Washington", "Oregon", "Arizona", "Colorado", "Illinois", "Michigan", "Ohio"]})

# Categorize states based on different criteria
us_states_df["political_affiliation"] = us_states_df["State"].apply(categorize_political_affiliation)
us_states_df["death_penalty_status"] = us_states_df["State"].apply(categorize_death_penalty)
us_states_df["geopolitical_region"] = us_states_df["State"].apply(categorize_geopolitical_region)

# Create three subplots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot for political affiliation
axs[0].set_title('Political Affiliation')
for index, row in us_states_df.iterrows():
    state = row["State"]
    political_affiliation = row["political_affiliation"]
    axs[0].scatter(state, 0, color='blue' if political_affiliation == 'Democratic' else 'red' if political_affiliation == 'Republican' else 'gray')

# Plot for death penalty status
axs[1].set_title('Death Penalty Status')
for index, row in us_states_df.iterrows():
    state = row["State"]
    death_penalty_status = row["death_penalty_status"]
    axs[1].scatter(state, 0, color='green' if death_penalty_status == 'Active' else 'orange')

# Plot for geopolitical region
axs[2].set_title('Geopolitical Region')
for index, row in us_states_df.iterrows():
    state = row["State"]
    geopolitical_region = row["geopolitical_region"]
    axs[2].scatter(state, 0, color='purple' if geopolitical_region == 'Northeast' else 'blue' if geopolitical_region == 'Midwest' else 'green' if geopolitical_region == 'South' else 'orange' if geopolitical_region == 'West' else 'gray')

# Hide axes
for ax in axs:
    ax.get_yaxis().set_visible(False)

plt.tight_layout()
plt.show()

# %%
import folium
import pandas as pd
import matplotlib.pyplot as plt

# Define functions to categorize states based on different criteria
def categorize_political_affiliation(state):
    democratic_states = ["California", "New York", "Massachusetts", "Washington", "Oregon", "Minnesota", "Hawaii"]
    republican_states = ["Texas", "Florida", "Georgia", "Ohio", "North Carolina", "Idaho", "Wyoming", "Utah", "Alaska", "Oklahoma", "Kansas", "Nebraska", "South Dakota", "North Dakota", "Alabama", "Mississippi", "South Carolina"]
    
    if state in democratic_states:
        return "Democratic"
    elif state in republican_states:
        return "Republican"
    else:
        return "Unknown"

def categorize_death_penalty(state):
    death_penalty_states = ["Texas", "Florida", "Georgia", "Ohio", "Oklahoma", "Montana", "Idaho","Nevada", "Utah", "Wyoming", "South Dakota", "Nebraska", "Kansas", "Arkansas", "Louisiana", "Mississippi","Alabama", "South Carolina", "North Carolina", "Kentucky", "Indiana"]
    
    if state in death_penalty_states:
        return "Active"
    else:
        return "Inactive"

def categorize_geopolitical_region(state):
    northeast_states = ["Connecticut", "Maine", "Massachusetts", "New Hampshire", "Rhode Island", "Vermont", "New York", "New Jersey", "Pennsylvania"]
    midwest_states = ["Illinois", "Indiana", "Michigan", "Ohio", "Wisconsin", "Iowa", "Kansas", "Minnesota", "Missouri", "Nebraska", "North Dakota", "South Dakota"]
    south_states = ["Delaware", "Florida", "Georgia", "Maryland", "North Carolina", "South Carolina", "Virginia", "West Virginia", "Alabama", "Kentucky", "Mississippi", "Tennessee", "Arkansas", "Louisiana", "Oklahoma", "Texas"]
    west_states = ["Arizona", "Colorado", "Idaho", "Montana", "Nevada", "New Mexico", "Utah", "Wyoming", "Alaska", "California", "Hawaii", "Oregon", "Washington"]
    
    if state in northeast_states:
        return "Northeast"
    elif state in midwest_states:
        return "Midwest"
    elif state in south_states:
        return "South"
    elif state in west_states:
        return "West"
    else:
        return "Unknown"

# Load state names
us_states_df = pd.DataFrame({"State": ["California", "Texas", "Florida", "New York", "Washington", "Oregon", "Arizona", "Colorado", "Illinois", "Michigan", "Ohio"]})

# Categorize states based on different criteria
us_states_df["political_affiliation"] = us_states_df["State"].apply(categorize_political_affiliation)
us_states_df["death_penalty_status"] = us_states_df["State"].apply(categorize_death_penalty)
us_states_df["geopolitical_region"] = us_states_df["State"].apply(categorize_geopolitical_region)

# Create three subplots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot for political affiliation
axs[0].set_title('Political Affiliation')
for index, row in us_states_df.iterrows():
    state = row["State"]
    political_affiliation = row["political_affiliation"]
    
    # Define color based on political affiliation
    if political_affiliation == "Democratic":
        color = "blue"
    elif political_affiliation == "Republican":
        color = "red"
    else:
        color = "gray"
    
    # Create a folium map for each subplot
    m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)
    folium.Marker(location=[0, 0], tooltip=state, icon=folium.Icon(color=color)).add_to(m)
    m.save(f"political_affiliation_{state}.html")  # Save the map as HTML file
    axs[0].imshow(plt.imread(f"political_affiliation_{state}.html"))
    axs[0].axis('off')

# Plot for death penalty status
axs[1].set_title('Death Penalty Status')
for index, row in us_states_df.iterrows():
    state = row["State"]
    death_penalty_status = row["death_penalty_status"]
    
    # Define color based on death penalty status
    if death_penalty_status == "Active":
        color = "green"
    else:
        color = "orange"
    
    # Create a folium map for each subplot
    m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)
    folium.Marker(location=[0, 0], tooltip=state, icon=folium.Icon(color=color)).add_to(m)
    m.save(f"death_penalty_status_{state}.html")  # Save the map as HTML file
    axs[1].imshow(plt.imread(f"death_penalty_status_{state}.html"))
    axs[1].axis('off')

# Plot for geopolitical region
axs[2].set_title('Geopolitical Region')
for index, row in us_states_df.iterrows():
    state = row["State"]
    geopolitical_region = row["geopolitical_region"]
    
    # Define color based on geopolitical region
    if geopolitical_region == "Northeast":
        color = "purple"
    elif geopolitical_region == "Midwest":
        color = "orange"
    elif geopolitical_region == "South":
        color = "yellow"
    elif geopolitical_region == "West":
        color = "cyan"
    else:
        color = "gray"
    
    # Create a folium map for each subplot
    m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)
    folium.Marker(location=[0, 0], tooltip=state, icon=folium.Icon(color=color)).add_to(m)
    m.save(f"geopolitical_region_{state}.html")  # Save the map as HTML file
    axs[2].imshow(plt.imread(f"geopolitical_region_{state}.html"))
    axs[2].axis('off')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Input In [8], in <cell line: 55>()
#      69     folium.Marker(location=[0, 0], tooltip=state, icon=folium.Icon(color=color)).add_to(m)
#      70     m.save(f"political_affiliation_{state}.html")  # Save the map as HTML file
# ---> 71     axs[0].imshow(plt.imread(f"political_affiliation_{state}.html"))
#      72     axs[0].axis('off')
#      74 # Plot for death penalty status
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:2111, in imread(fname, format)
#    2109 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2110 def imread(fname, format=None):
# -> 2111     return matplotlib.image.imread(fname, format)
#
# ...

# %%
import folium
import pandas as pd
import webbrowser

# Define functions to categorize states based on different criteria
def categorize_political_affiliation(state):
    democratic_states = ["California", "New York", "Massachusetts", "Washington", "Oregon", "Minnesota", "Hawaii"]
    republican_states = ["Texas", "Florida", "Georgia", "Ohio", "North Carolina", "Idaho", "Wyoming", "Utah", "Alaska", "Oklahoma", "Kansas", "Nebraska", "South Dakota", "North Dakota", "Alabama", "Mississippi", "South Carolina"]
    
    if state in democratic_states:
        return "Democratic"
    elif state in republican_states:
        return "Republican"
    else:
        return "Unknown"

def categorize_death_penalty(state):
    death_penalty_states = ["Texas", "Florida", "Georgia", "Ohio", "Oklahoma", "Montana", "Idaho","Nevada", "Utah", "Wyoming", "South Dakota", "Nebraska", "Kansas", "Arkansas", "Louisiana", "Mississippi","Alabama", "South Carolina", "North Carolina", "Kentucky", "Indiana"]
    
    if state in death_penalty_states:
        return "Active"
    else:
        return "Inactive"

def categorize_geopolitical_region(state):
    northeast_states = ["Connecticut", "Maine", "Massachusetts", "New Hampshire", "Rhode Island", "Vermont", "New York", "New Jersey", "Pennsylvania"]
    midwest_states = ["Illinois", "Indiana", "Michigan", "Ohio", "Wisconsin", "Iowa", "Kansas", "Minnesota", "Missouri", "Nebraska", "North Dakota", "South Dakota"]
    south_states = ["Delaware", "Florida", "Georgia", "Maryland", "North Carolina", "South Carolina", "Virginia", "West Virginia", "Alabama", "Kentucky", "Mississippi", "Tennessee", "Arkansas", "Louisiana", "Oklahoma", "Texas"]
    west_states = ["Arizona", "Colorado", "Idaho", "Montana", "Nevada", "New Mexico", "Utah", "Wyoming", "Alaska", "California", "Hawaii", "Oregon", "Washington"]
    
    if state in northeast_states:
        return "Northeast"
    elif state in midwest_states:
        return "Midwest"
    elif state in south_states:
        return "South"
    elif state in west_states:
        return "West"
    else:
        return "Unknown"

# Load state names
us_states_df = pd.DataFrame({"State": ["California", "Texas", "Florida", "New York", "Washington", "Oregon", "Arizona", "Colorado", "Illinois", "Michigan", "Ohio"]})

# Categorize states based on different criteria
us_states_df["political_affiliation"] = us_states_df["State"].apply(categorize_political_affiliation)
us_states_df["death_penalty_status"] = us_states_df["State"].apply(categorize_death_penalty)
us_states_df["geopolitical_region"] = us_states_df["State"].apply(categorize_geopolitical_region)

# Create three subplots
for i, feature in enumerate(["political_affiliation", "death_penalty_status", "geopolitical_region"]):
    # Create a folium map for each feature
    m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)
    for index, row in us_states_df.iterrows():
        state = row["State"]
        value = row[feature]
        color = {
            "political_affiliation": {"Democratic": "blue", "Republican": "red", "Unknown": "gray"},
            "death_penalty_status": {"Active": "green", "Inactive": "orange"},
            "geopolitical_region": {"Northeast": "purple", "Midwest": "orange", "South": "yellow", "West": "cyan", "Unknown": "gray"}
        }[feature][value]
        folium.Marker(location=[0, 0], tooltip=state, icon=folium.Icon(color=color)).add_to(m)
    m.save(f"{feature}.html")  # Save the map as HTML file
    webbrowser.open_new_tab(f"{feature}.html")  # Open the HTML file in the default web browser
# Out:
# C:\Users\megan\AppData\Local\Temp\ipykernel_35160\226363726.py:62: UserWarning: color argument of Icon should be one of: {'red', 'orange', 'cadetblue', 'darkgreen', 'darkpurple', 'lightred', 'lightgreen', 'pink', 'white', 'blue', 'gray', 'green', 'black', 'lightgray', 'purple', 'lightblue', 'beige', 'darkred', 'darkblue'}.
#   folium.Marker(location=[0, 0], tooltip=state, icon=folium.Icon(color=color)).add_to(m)
